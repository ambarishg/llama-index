# %%
# %pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 929 kB 16.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 19.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 221 kB 46.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.3 MB 27.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 664 kB 41.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 83 kB 1.6 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 49 kB 4.9 MB/s  eta 0:00:01
# ...
# ERROR: gradio 3.36.1 has requirement huggingface-hub>=0.14.0, but you'll have huggingface-hub 0.13.4 which is incompatible.
# ...
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.5.6
#     Uninstalling nest-asyncio-1.5.6:
#       Successfully uninstalled nest-asyncio-1.5.6
#   Attempting uninstall: openai
#     Found existing installation: openai 0.27.8
#     Uninstalling openai-0.27.8:
#       Successfully uninstalled openai-0.27.8
# ...
